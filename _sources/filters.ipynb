# %% [markdown]
# # Filters

# %%
import numpy as np

# %%
f = np.random.random((3,3))

# %%
f
# Out:
# array([[0.80571467, 0.45860679, 0.72150406],
#        [0.75201729, 0.30799577, 0.81739908],
#        [0.92082202, 0.72668369, 0.05008615]])
